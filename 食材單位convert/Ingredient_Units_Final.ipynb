# %%
in_file = open('item_counts.csv','r')
out_file = open('All-units.txt','w')
ingre_counts = open('ingre_counts.txt','w')
   
def col(line, n):
    Qaa = line.split(',')[0].strip()+','+line.split(',')[1].strip()+','
    print Qaa
    ingre_counts.write(Qaa+line.split(',')[2]+'\n')
    try:
        while (line.split(',')[n+1] is not ''):
            if (line.split(',')[n] is not '') and (line.split(',')[n+1] is not ''):
                out_file.write(Qaa+line.split(',')[n].strip()+','+''+'\n')
                print Qaa+line.split(',')[n].strip()+','+''+'\n'
            else: 
                pass
            n += 2
        return
    except:
        pass
for line in in_file.readlines():
    col(line, 3)   

ingre_counts.close()
out_file.close()
in_file.close()


#remove 單位是數字 及 單位有括號 的rows
import re
aaa = open('All-units.txt','r')
bbb = open('All-units-clean.txt','w')
for i in aaa.readlines():
    ii = i.split(',')[2]
    m = re.match(r'(\d+)', ii)
    if m:
        pass
    else:
        if '(' in ii:
            iii = ii.split('(')[0]
            bbb.write(i.split(',')[0]+','+i.split(',')[1]+','+iii+',\n')
        elif '（' in ii:
            jjj = ii.split('（')[0]
            bbb.write(i.split(',')[0]+','+i.split(',')[1]+','+jjj+',\n')
        else:
            bbb.write(i)
bbb.close()
aaa.close()

# %%
in_file = open('All-units-clean.txt','r')
out_file = open('All-units-details.txt','w')
out_file2 = open('units-not-match.txt','w')
out_file3 = open('units-not-match.csv','w')

Aaa=[]
for line in in_file.readlines():
    cat= line.split(',')[0].strip()
    #print cat
    ingre= line.split(',')[1].strip()
    #print ingre
    unit= line.split(',')[2].strip()
    #print unit
    main = cat +','+ ingre + ','+unit
    
    g = ['公克','g','cc', 'CC', 'ml', 'ML', '克', 'c.c.', 'ｇ','克上下','個克','g.','西西','g 切片','g以上',
         'G', '㏄', 'c.c', 'C.C', 'ＣＣ', 'C.C.', 'Ｃ.Ｃ.', 'ｃｃ','C C','課','g　','m左右','nl','克克',
         '毫升', '公公克', '公克。', '公克.', 'cc.', '㏄。', 'mg', 'cc左右','cc上下','cc要淹過肉','gm','g刨絲',
         'Cc','CC.','cc內','cc以上','cc適量','cc左右','g切片','Ｇ','克對切','克切丁','克左右','ｍｌ','mL','ml 毫升',
         'mL','ml.','ml左右','克隨意','功克','G 增減']
    
    oz = ['盎司', 'oz', 'OZ','ounce','盎斯']
    
    T = ['大匙', '湯匙', 'T', '大湯匙', '大匙滿', '大匙半', '大匙量','/大匙', '大匙。', '桌匙', '大Ｔ', 'tbsp', 'table spoon', 
         '鐵湯匙', 'Tbsp','大匙以上','湯匙份', '喝湯匙', 'TABLE', '大T','大匙和1小匙', '大匙又.25小匙','大匙又2','湯勺',
         '大勺','大湯杓','Ts', '杯1TBSP','大湯勺','大勺','湯瓢','尖湯匙','大湯瓢','木瓢']
    
    t = ['小匙', '茶匙', 't', '中匙', '花匙', '/茶匙', '洗匙', '大茶匙', '小茶匙','tsb', 'tsp','tsps', 'TEA', '咖啡匙',
         '小尟', '中平匙','勺','菜匙','甜匙','小匙3','小匙斟酌','布丁匙','TSP', 'teaspoon','分滿小匙','點點提味','小湯匙',
        '平小勺', '匙多', '小匙3g', '鹽罐小匙','小匙＿', '小匙鹽', '小匙滿', '小小匙', '小匙多1點', '小匙滿滿像小山', 
         '又0.75小匙', 't小匙', '小匙5ml', '根小匙', '茶匙份量','尖茶匙','小匙適量','瓶蓋','匙 tsp']
    
    C = ['杯','量杯', '小碗','杯量','杯滿', '杯。','杯左右', '飯碗', 'cup', 'Cup', '量米杯','柸','杯米杯','茶杯','茶杯','杯量杯',
         '杯切碎的核桃','杯米杯','茶碗','個茶碗量','茶碗量','小茶碗量','杯份','杯米','杯米量','馬克杯量','平米杯','平杯','米糧杯',
         '杯量米杯', '米杯','客','小杯','cup 杯','茶杯','米量杯','馬克杯','杯牛奶','分滿碗','杯融化奶油','米量杯','CUP','cups',
        '紙杯','分滿量杯','個米杯','的量杯','米量杯','個米杯滿','燜燒杯','杯至1杯','個米杯','杯米量']
    
    B = ['大碗', '大杯','湯碗', '杯左右', '飯碗', '碗量', '碗切丁','碗份量','分滿碗','飯碗1大匙','碗多','碗公量', '個飯碗',
         '飯碗量','尖碗','碗','婉','平碗','倇','大碗公','個大茶碗量','大茶碗','大茶碗量','碗白飯','碗飯量','琬','豌',
        '碗切絲',]
    
    kg = ['公斤', 'kg', 'KG', '公升', '斤半', 'kg左右','kilogram','塊1公斤', 'Liter','liter']
    
    tael = ['兩']
    
    pb = ['磅', 'lb','磅。','塊.500g']
    
    catty = ['斤', '斤或10', '隻約1斤', '斤切塊', '台斤','筋','斤盒','巾','斤多','隻1斤','斤1條','斤重']

    Seasoning_3g = ['少許', '少匙', '撮', '粒', '小粒','稍許', '數葉', '數片', '錢', '些許', '滴','數滴','少量',
                   '附', '只', '對', '副', '付', '錢5分', '錢2分', '微量', '辦','辮', '顆末', '粒量', '又0.5小匙', 'tsp少少', 
                    '指尖', '又0.5茶匙', 'g匙', '又0.25茶匙', '小掫', '點點不到1g','咪咪咪','分之1茶匙', '鹽罐量匙', '丁點', '小搓',
                   '個指腹量','小指腹量', '絲絲', '滴滴', '小戳', '些些', '咪咪', '又0.25小匙', '+.5小匙', '又4分之1小匙',
                   '均可','百克', '自行斟酌','塊錢','小截','小圓片','小瓣','粒切絲','粒切粒','梗','莖','片葉','莢','夾','葉片',
                    '個雞蛋','顆蛋量','顆小','顆份','顆蛋','個蛋量','顆雞蛋','片葉子','長瓣','柄葉子','pcs']
    
    Seasoning_6g = ['適量', '酌量', '瓣', '片量', '片', '切片', '小把','小把的量', '小段','小塊','小包','包', '札', '卷', '札',
                    '小束','小片','圈','塊', '段節', '節', '跟', 'cl', '小支', '小節', '大葉','塊切塊','塊左右','塊大小',
                    '捲', '大朵', '串', '綑', '個切末', '小珠','個量','個份量', '公分厚', '個份','小份','小張','顆的量',
                    '株', '小枝','小條','小細條','小顆', '小棵','整顆','大棵','打','顆','顆中型','棵','頛','個檸檬','顆小',
                    '小稞', '顆對切','顆以上','顆量', '塊土司',
                    '顆半','顆。','顆切小丁','個切小丁','顆切絲','顆切塊','顆 切碎','顆 切細丁',
                    '個 切末','顆切大丁','顆 切絲','顆切丁','個﹝去衣切件﹞','顆切碎','顆縱切細絲','顆切小塊','根','根量', '根切丁',
                    '小片段','小根切絲','條切塊','棵斜切片','條切絲','條切片','個 切薄片','個切成塊狀','顆去籽切丁','顆 去皮切丁',
                    '根切圓片','個','個分','個、','份', '小朵', '來朵','朵切丁','躲','朵切小片','小株', '小個', '小根', '隨意', '小撮',
                    '個番茄','顆適量','科','朵中型','粒左右','朵切末'
                   '尾','面','條切丁', '手掌', '捆', '小梱','小捆', '枚', '公分段' , '公靠', 'cm','cm1根','公分長度','公分長切塊','CM','大支', 
                    '盤225g', '整條',
                    '架', '片切條','騙','小切片','片切丁','薄片','片切絲','大厚片','片花','大支量','長片','條.','片切絲','片切段','片左右',
                    '條切末','條撕碎','根對切','元左右','根斜切片','根切片','小球','小捲','扎','紮','塊裝','小坨','團','陀', 
                   '小尾','大尾','絛','來顆','來個','來隻','根','來根','根切段','坨','鬃','小磚','小立方塊','大段']
    
    Seasoning_9g = ['大片', '段', '條', '數瓣','茶包','大株', '袋','磚','大堆', '束', '小個', '張', '大把', '大顆', '大個', 
                    '長條', '數粒'
                    '公分', '公分長', '把', '支','枝', '大塊', '球', '球）', '大球','大根', '大張', '數條', '大條', '大包', 
                    '數個','幾朵','數朵',  '人份', '大粒', '吋1個', '數張', '吋1片', '元', '公隻','數顆','件','糰', '厚片','隻鴨腿的量',
                   '棒腿的量','隻雞腿量','隻雞腿肉的份量','數尾','幾隻','多隻','個腿排','整副','大串','顆蘋果','顆切片','條 中型',
                   '大疊','數瓣','瓣的量','幾顆','大堆','條切小丁','條˙','條香蕉的量','根　','條）',]
    
    Seasoning_40g = ['小罐','小罐份', '小瓶', '盒', '鍋', '小碟', '整隻','小隻','小排','組', '格', '小盒','隻`','隻切小塊', '隻剁開',
                     '隻', '小拳頭','個拳頭大', 
                     '巴掌','個拳頭', '隻量', '隻切塊','個拳頭大小','個拳頭份量','拳大小','小件','大串','小盤']
    
    Seasoning_80g = ['罐', '大罐','瓶', '鍋', '盤', '板', '全部', '大盒','大付','大件','數支','數隻','大隻', '架','大份','小袋',
                     '掛','隻雞的分量','個罐頭','灌','冠','大盤','帖']
    
    smallEggBean = ['黑豆', '杏仁', '黃豆', '豆包', '葵瓜子', '腰果', '開心果', '米豆', '蛋皮', '堅果', 
                    '蓮子', '甜豆', '栗子', '綠豆', '松子仁', '花生', '核桃', '豌豆', '愛玉子', '決明子', '納豆'
                   '鷹嘴豆', '夏威夷豆','無花果', '腐皮', '味噌']

    smallSeafood = ['蛤', '蝦', '干貝', '九孔', '蝦仁', '櫻花蝦', '螺', '海參', '蝦皮', '蟹腳', '扇貝', 
                    '蝦蛄', '蟹肉','蝦米','海瓜子','海蜇皮']
    
    smallPowder = ['薏仁', '蒟蒻', '粉圓', ]
    
    if any(unit in item for item in g):
        Aaa.append(main + ',1')
    elif any(unit in item for item in oz):
        Aaa.append(main + ',28')
    elif any(unit in item for item in T):
        Aaa.append(main + ',15')
    elif any(unit in item for item in t):
        Aaa.append(main + ',5')
    elif any(unit in item for item in C):
        Aaa.append(main + ',230')
    elif any(unit in item for item in B):
        Aaa.append(main + ',330')
    elif any(unit in item for item in tael):
        Aaa.append(main + ',37.5')
    elif any(unit in item for item in pb):
        Aaa.append(main + ',455')        
    elif any(unit in item for item in catty):
        Aaa.append(main + ',605')
    elif any(unit in item for item in kg):
        Aaa.append(main + ',1000')
    elif cat == 'K' and any(unit in item for item in Seasoning_3g):
        Aaa.append(main + ',3')
    elif cat == 'K' and any(unit in item for item in Seasoning_6g):
        Aaa.append(main + ',6')
    elif cat == 'K' and any(unit in item for item in Seasoning_9g):
        Aaa.append(main + ',9')
    elif cat == 'K' and any(unit in item for item in Seasoning_40g):
        Aaa.append(main + ',40')
    elif cat == 'K' and any(unit in item for item in Seasoning_80g):
        Aaa.append(main + ',80')
    elif cat == 'G' and any(unit in item for item in Seasoning_3g):
        Aaa.append(main + ',20')
    elif cat == 'G' and any(unit in item for item in Seasoning_6g):
        Aaa.append(main + ',40')
    elif cat == 'G' and any(unit in item for item in Seasoning_9g):
        Aaa.append(main + ',120')
    elif cat == 'G' and any(unit in item for item in Seasoning_40g):
        Aaa.append(main + ',160')
    elif cat == 'G' and any(unit in item for item in Seasoning_80g):
        Aaa.append(main + ',200')
    elif any(ingre in i for i in smallEggBean) and any(unit in item for item in Seasoning_3g):
        Aaa.append(main + ',20')
    elif any(ingre in i for i in smallEggBean) and any(unit in item for item in Seasoning_6g):
        Aaa.append(main + ',25')
    elif any(ingre in i for i in smallEggBean) and any(unit in item for item in Seasoning_9g):
        Aaa.append(main + ',30')
    elif cat == 'H' and any(unit in item for item in Seasoning_3g):
        Aaa.append(main + ',50')
    elif cat == 'H' and any(unit in item for item in Seasoning_6g):
        Aaa.append(main + ',60')
    elif cat == 'H' and any(unit in item for item in Seasoning_9g):
        Aaa.append(main + ',120')
    elif cat == 'H' and any(unit in item for item in Seasoning_40g):
        Aaa.append(main + ',300')
    elif cat == 'H' and any(unit in item for item in Seasoning_80g):
        Aaa.append(main + ',350')
    elif 'A' in cat and any(unit in item for item in Seasoning_3g):
        Aaa.append(main + ',150')
    elif 'A' in cat and any(unit in item for item in Seasoning_6g):
        Aaa.append(main + ',200')
    elif 'A' in cat and any(unit in item for item in Seasoning_9g):
        Aaa.append(main + ',250')
    elif 'A' in cat and any(unit in item for item in Seasoning_40g):
        Aaa.append(main + ',300')
    elif 'A' in cat and any(unit in item for item in Seasoning_80g):
        Aaa.append(main + ',400')
    elif 'B' in cat and any(unit in item for item in Seasoning_3g):
        Aaa.append(main + ',150')
    elif 'B' in cat and any(unit in item for item in Seasoning_6g):
        Aaa.append(main + ',200')
    elif 'B' in cat and any(unit in item for item in Seasoning_9g):
        Aaa.append(main + ',250')
    elif 'B' in cat and any(unit in item for item in Seasoning_40g):
        Aaa.append(main + ',300')
    elif 'B' in cat and any(unit in item for item in Seasoning_80g):
        Aaa.append(main + ',400')
    elif 'C' in cat and any(unit in item for item in Seasoning_3g):
        Aaa.append(main + ',150')
    elif 'C' in cat and any(unit in item for item in Seasoning_6g):
        Aaa.append(main + ',200')
    elif 'C' in cat and any(unit in item for item in Seasoning_9g):
        Aaa.append(main + ',250')
    elif 'C' in cat and any(unit in item for item in Seasoning_40g):
        Aaa.append(main + ',300')
    elif 'C' in cat and any(unit in item for item in Seasoning_80g):
        Aaa.append(main + ',400')
    elif 'D' in cat and any(unit in item for item in Seasoning_3g):
        Aaa.append(main + ',150')
    elif 'D' in cat and any(unit in item for item in Seasoning_6g):
        Aaa.append(main + ',200')
    elif 'D' in cat and any(unit in item for item in Seasoning_9g):
        Aaa.append(main + ',250')
    elif 'D' in cat and any(unit in item for item in Seasoning_40g):
        Aaa.append(main + ',300')
    elif 'D' in cat and any(unit in item for item in Seasoning_80g):
        Aaa.append(main + ',400')
    elif 'E' in cat and any(unit in item for item in Seasoning_3g):
        Aaa.append(main + ',150')
    elif 'E' in cat and any(unit in item for item in Seasoning_6g):
        Aaa.append(main + ',200')
    elif 'E' in cat and any(unit in item for item in Seasoning_9g):
        Aaa.append(main + ',250')
    elif 'E' in cat and any(unit in item for item in Seasoning_40g):
        Aaa.append(main + ',300')
    elif 'E' in cat and any(unit in item for item in Seasoning_80g):
        Aaa.append(main + ',400')
    elif any(ingre in i for i in smallSeafood) and any(unit in item for item in Seasoning_3g):
        Aaa.append(main + ',20')
    elif any(ingre in i for i in smallSeafood) and any(unit in item for item in Seasoning_6g):
        Aaa.append(main + ',30')
    elif any(ingre in i for i in smallSeafood) and any(unit in item for item in Seasoning_9g):
        Aaa.append(main + ',50')
    elif cat == 'F' and any(unit in item for item in Seasoning_3g):
        Aaa.append(main + ',100')
    elif cat == 'F' and any(unit in item for item in Seasoning_6g):
        Aaa.append(main + ',150')
    elif cat == 'F'  and any(unit in item for item in Seasoning_9g):
        Aaa.append(main + ',200')
    elif cat == 'F'  and any(unit in item for item in Seasoning_40g):
        Aaa.append(main + ',220')
    elif cat == 'F' and any(unit in item for item in Seasoning_80g):
        Aaa.append(main + ',250')
    elif cat == 'I' and any(unit in item for item in Seasoning_3g):
        Aaa.append(main + ',3')
    elif cat == 'I' and any(unit in item for item in Seasoning_6g):
        Aaa.append(main + ',6')
    elif cat == 'I' and any(unit in item for item in Seasoning_9g):
        Aaa.append(main + ',9')
    elif cat == 'I' and any(unit in item for item in Seasoning_40g):
        Aaa.append(main + ',40')
    elif cat == 'I' and any(unit in item for item in Seasoning_80g):
        Aaa.append(main + ',80')
    elif any(ingre in i for i in smallPowder) and any(unit in item for item in Seasoning_3g):
        Aaa.append(main + ',3')
    elif any(ingre in i for i in smallPowder) and any(unit in item for item in Seasoning_6g):
        Aaa.append(main + ',6')
    elif any(ingre in i for i in smallPowder) and any(unit in item for item in Seasoning_9g):
        Aaa.append(main + ',9')
    elif cat == 'J' and any(unit in item for item in Seasoning_3g):
        Aaa.append(main + ',150')
    elif cat == 'J' and any(unit in item for item in Seasoning_6g):
        Aaa.append(main + ',200')
    elif cat == 'J' and any(unit in item for item in Seasoning_9g):
        Aaa.append(main + ',250')
    elif cat == 'J' and any(unit in item for item in Seasoning_40g):
        Aaa.append(main + ',300')
    elif cat == 'J' and any(unit in item for item in Seasoning_80g):
        Aaa.append(main + ',350')
    elif cat == 'L' and any(unit in item for item in Seasoning_3g):
        Aaa.append(main + ',30')
    elif cat == 'L' and any(unit in item for item in Seasoning_6g):
        Aaa.append(main + ',80')
    elif cat == 'L' and any(unit in item for item in Seasoning_9g):
        Aaa.append(main + ',120')
    elif cat == 'L' and any(unit in item for item in Seasoning_40g):
        Aaa.append(main + ',150')
    elif cat == 'L' and any(unit in item for item in Seasoning_80g):
        Aaa.append(main + ',200')
    elif ingre == '水':#水多重都沒差
        Aaa.append(main + ',0')
    else:
        Aaa.append(main+',')
        
        
for i in Aaa:
    cat = i.split(',')[0]
    ingre = i.split(',')[1]
    unit = i.split(',')[2]
    wt = i.split(',')[3]
    out_file.write(unit+','+ingre+','+wt+','+cat+'\n')
        
#還沒有單位的        
for i in Aaa:
    if i.split(',')[3] == '':
        print i
        out_file2.write(i+"\n")
        out_file3.write(i+"\n")

out_file2.close()        
out_file.close()
in_file.close()
# Out:
# K,食鹽,:10,
# K,食鹽,／8茶匙,
# K,食鹽,／2大匙,
# K,食鹽,\4茶匙,
# K,食鹽,至3匙,
# K,食鹽,茶匙的0.5個,
# K,食鹽,匙尖,
# K,食鹽,／2茶匙,
# K,食鹽,小題,
# K,食鹽,又0.5甜匙,
# K,食鹽,／4茶匙,
# K,食鹽,tsp 茶匙,
# K,食鹽,小匙x2,
# K,食鹽,／2小匙,
# K,食鹽,至3杯,
# K,食鹽,: 2 : 0.5 : 0.5 : 0.5,
# K,食鹽,分之1 茶匙,
# K,食鹽,面1匙,
# K,食鹽,月2日,
# K,食鹽,分之1大匙,
# K,食鹽,至3湯匙,
# K,食鹽,月4日,
# K,食鹽,匙x 3,
# K,食鹽,小瓢,
# K,食鹽,分之1匙,
# K,食鹽,又0.5大匙,
# K,食鹽,tp,
# K,食鹽,／4小匙,
# K,食鹽,呎,
# K,食鹽,小平匙,
# K,食鹽,茶匙　,
# K,砂糖,Tbsps,
# K,砂糖,包0元,
# K,砂糖,大匙左右,
# K,砂糖,分之3量米杯,
# K,砂糖,:02:01,
# K,砂糖,／2匙,
# K,砂糖,杯糖,
# K,砂糖,／2茶匙,
# K,砂糖,杯＋2 大匙,
# K,砂糖,／2大匙,
# K,砂糖,又0.5大匙,
# K,砂糖,又0.33 杯,
# K,砂糖,大醬,
# K,砂糖,＋10 公克,
# K,砂糖,／2小匙,
# K,砂糖,+.5大匙,
# K,砂糖,:10,
# K,砂糖,g外加最後灑在麵糊頂上1大匙,
# K,砂糖,.5ml,
# K,砂糖,杯多,
# K,砂糖,#NAME?,
# K,砂糖,月2日,
# K,砂糖,分之1湯匙,
# K,砂糖,分之1杯,
# K,砂糖,%,
# K,砂糖,小T,
# K,砂糖,又0.5cup,
# K,砂糖,又0.5杯,
# K,砂糖,小時,
# K,砂糖,／3杯,
# K,砂糖,分之1匙,
# K,砂糖,　g,
# K,砂糖,－200g,
# K,蒜,瓣大蒜,
# K,蒜,辦拍扁,
# K,蒜,顆左右,
# K,蒜,顆切成細末,
# K,蒜,瓣20g,
# K,蒜,個切片,
# K,蒜,瓣 壓泥,
# K,蒜,月3日,
# K,蒜,瓣拍過,
# K,蒜,瓣量,
# K,蒜,粒蒜頭,
# K,蒜,瓣切片,
# K,蒜,多顆,
# ...
