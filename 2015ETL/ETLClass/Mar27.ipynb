# %%
from bs4 import BeautifulSoup 
import re, requests 
res = requests.get("http://web.pcc.gov.tw/tps/main/pms/tps/atm/atmAwardAction.do?newEdit=false&searchMode=common&method=inquiryForPublic&pkAtmMain=51081295&tenderCaseNo=102-0400-1-051")
soup = BeautifulSoup(res.text.encode('utf-8'))
#print soup
printArea  = soup.select("#printArea")[0]

f = open("51081295_102-0400-1-051.txt", 'w')
f.write(printArea.prettify('utf-8'))
f.close()

f = open("51081295_102-0400-1-051.txt", "r") 
response_text = f.read()
f.close()

soup = BeautifulSoup(response_text) 
tr = soup.select('tr')
'''for row in tr: 
    if len(row.select('th')) >0:
        print row.select('th')[0].text.strip()
        
for row in tr: 
    th = row.find('th') 
    if th is not None: 
    if th.text.encode('utf-8').strip() == "機關代碼": 
        print row.find('td').text.strip() 
    if th.text.encode('utf-8').strip() == "機關名稱": 
        print row.find('td').text.strip() 
    if th.text.encode(‘utf-8’).strip() == “單位名稱": 
    print row.find('td').text.strip()
'''

dic = {"機關代碼":"", "機關名稱":"", "機關地址":""}
dic["聯絡人"] = ""
#print dic
#for item in dic:
#    print item, dic[item]
for row in tr: 
    th = row.find('th') 
    if th is not None: 
        if th.text.encode('utf-8').strip() in dic: 
            dic[th.text.encode('utf-8').strip()] = row.find('td').text.strip()

for item in dic:
    print item, dic[item]
# Out:
# 聯絡人 張淑英
# 機關名稱 臺灣菸酒股份有限公司隆田酒廠
# 機關代碼 3.7.74.37
# 機關地址 720臺南市官田區隆本里中華路一段335號

# %%
dic = {"標的分類":""} 
for row in tr: 
    th = row.find('th') 
    if th is not None: 
        if th.text.encode('utf-8').strip() in dic: 
            dic[th.text.encode('utf-8').strip()] = row.find('td').text.encode('utf-8').strip() 
for rec in dic: 
    print rec, dic[rec]
# Out:
# 標的分類 <財物類>
#                             32
#                             紙漿,紙及紙產品;印刷品及相關的商品

# %%
a = '\t\t string \n\t' 
print a 
print repr(a)
# Out:
# 		 string
#
# '\t\t string \n\t'

# %%
print dic
# Out:
# {'\xe6\xa8\x99\xe7\x9a\x84\xe5\x88\x86\xe9\xa1\x9e': ''}

# %%
a = '123,555,111,99' 
print a.split(',') 
b = a.split(',',1)

print a.split(',')[2:]

x = a.split(',') 
print '$'.join(x)
# Out:
# ['123', '555', '111', '99']
# ['111', '99']
# 123$555$111$99

# %%
for rec in dic: 
    print ''.join(dic[rec].split())
# Out:
# <財物類>32紙漿,紙及紙產品;印刷品及相關的商品

# %%
#-*- coding: utf-8 -*-
a = '''2009.12.2【大明星指定菜】酸辣湯餃,阿基師教你做─酸辣湯餃,
大明星指定菜,酸辣湯餃,食材：,水餃皮8片、豬絞肉100g、高麗菜100g、新鮮黑木耳1片、
去皮蒜頭3顆、薑末、鴨血1塊、板豆腐1塊、太白粉1小碗(勾芡比例,粉1：水3)、紅蘿蔔半根、
全蛋1顆、蔥花1碗、紅油,調味料：,鹽巴、香油、白胡椒粉、醬油、白醋、烏醋,做法,1.,
備料：黑木耳切絲、高麗菜切末、鴨血切絲、板豆腐切絲，紅蘿蔔刨絲，備用。,2.,
取一水晶碗，放入高麗菜末、少許鹽抓醃3分鐘，擠出水備用。,3.,內餡：取一水晶碗，放入豬絞肉、少許薑末、
少許蔥花、少許醬油一起混合抓醃，再加入少許香油、高麗菜末混勻，接著將內餡包入水餃皮中，
將上下兩邊皮對折粘起，用虎口的力量擠壓成元寶狀備用。,4.,起滾水鍋，放入少許鹽巴，將水餃入鍋煮熟，
即可盛起放在成品碗中，淋上少許紅油，備用。,5.,起鍋加入煮水餃的水適量，放入紅蘿蔔絲、黑木耳絲、
板豆腐絲、鴨血絲、再加入少許醬油、太白粉勾芡，接著灑入胡椒粉、淋入白醋拌勻，倒入成品碗內，
最後灑上蔥花，淋上蛋液，在灑上胡椒粉、香油提香即完成。,'''
#b = a.encode('utf-8')
print a.split(',')
print b.split(',',1)
print b.split(',',2)
# Out:
# ['2009.12.2\xe3\x80\x90\xe5\xa4\xa7\xe6\x98\x8e\xe6\x98\x9f\xe6\x8c\x87\xe5\xae\x9a\xe8\x8f\x9c\xe3\x80\x91\xe9\x85\xb8\xe8\xbe\xa3\xe6\xb9\xaf\xe9\xa4\x83', '\xe9\x98\xbf\xe5\x9f\xba\xe5\xb8\xab\xe6\x95\x99\xe4\xbd\xa0\xe5\x81\x9a\xe2\x94\x80\xe9\x85\xb8\xe8\xbe\xa3\xe6\xb9\xaf\xe9\xa4\x83', '\n\xe5\xa4\xa7\xe6\x98\x8e\xe6\x98\x9f\xe6\x8c\x87\xe5\xae\x9a\xe8\x8f\x9c', '\xe9\x85\xb8\xe8\xbe\xa3\xe6\xb9\xaf\xe9\xa4\x83', '\xe9\xa3\x9f\xe6\x9d\x90\xef\xbc\x9a', '\xe6\xb0\xb4\xe9\xa4\x83\xe7\x9a\xae8\xe7\x89\x87\xe3\x80\x81\xe8\xb1\xac\xe7\xb5\x9e\xe8\x82\x89100g\xe3\x80\x81\xe9\xab\x98\xe9\xba\x97\xe8\x8f\x9c100g\xe3\x80\x81\xe6\x96\xb0\xe9\xae\xae\xe9\xbb\x91\xe6\x9c\xa8\xe8\x80\xb31\xe7\x89\x87\xe3\x80\x81\n\xe5\x8e\xbb\xe7\x9a\xae\xe8\x92\x9c\xe9\xa0\xad3\xe9\xa1\x86\xe3\x80\x81\xe8\x96\x91\xe6\x9c\xab\xe3\x80\x81\xe9\xb4\xa8\xe8\xa1\x801\xe5\xa1\x8a\xe3\x80\x81\xe6\x9d\xbf\xe8\xb1\x86\xe8\x85\x901\xe5\xa1\x8a\xe3\x80\x81\xe5\xa4\xaa\xe7\x99\xbd\xe7\xb2\x891\xe5\xb0\x8f\xe7\xa2\x97(\xe5\x8b\xbe\xe8\x8a\xa1\xe6\xaf\x94\xe4\xbe\x8b', '\xe7\xb2\x891\xef\xbc\x9a\xe6\xb0\xb43)\xe3\x80\x81\xe7\xb4\x85\xe8\x98\xbf\xe8\x94\x94\xe5\x8d\x8a\xe6\xa0\xb9\xe3\x80\x81\n\xe5\x85\xa8\xe8\x9b\x8b1\xe9\xa1\x86\xe3\x80\x81\xe8\x94\xa5\xe8\x8a\xb11\xe7\xa2\x97\xe3\x80\x81\xe7\xb4\x85\xe6\xb2\xb9', '\xe8\xaa\xbf\xe5\x91\xb3\xe6\x96\x99\xef\xbc\x9a', '\xe9\xb9\xbd\xe5\xb7\xb4\xe3\x80\x81\xe9\xa6\x99\xe6\xb2\xb9\xe3\x80\x81\xe7\x99\xbd\xe8\x83\xa1\xe6\xa4\x92\xe7\xb2\x89\xe3\x80\x81\xe9\x86\xac\xe6\xb2\xb9\xe3\x80\x81\xe7\x99\xbd\xe9\x86\x8b\xe3\x80\x81\xe7\x83\x8f\xe9\x86\x8b', '\xe5\x81\x9a\xe6\xb3\x95', '1.', '\n', '2.', '\n\xe5\x8f\x96\xe4\xb8\x80\xe6\xb0\xb4\xe6\x99\xb6\xe7\xa2\x97\xef\xbc\x8c\xe6\x94\xbe\xe5\x85\xa5\xe9\xab\x98\xe9\xba\x97\xe8\x8f\x9c\xe6\x9c\xab\xe3\x80\x81\xe5\xb0\x91\xe8\xa8\xb1\xe9\xb9\xbd\xe6\x8a\x93\xe9\x86\x833\xe5\x88\x86\xe9\x90\x98\xef\xbc\x8c\xe6\x93\xa0\xe5\x87\xba\xe6\xb0\xb4\xe5\x82\x99\xe7\x94\xa8\xe3\x80\x82', '3.', '\xe5\x85\xa7\xe9\xa4\xa1\xef\xbc\x9a\xe5\x8f\x96\xe4\xb8\x80\xe6\xb0\xb4\xe6\x99\xb6\xe7\xa2\x97\xef\xbc\x8c\xe6\x94\xbe\xe5\x85\xa5\xe8\xb1\xac\xe7\xb5\x9e\xe8\x82\x89\xe3\x80\x81\xe5\xb0\x91\xe8\xa8\xb1\xe8\x96\x91\xe6\x9c\xab\xe3\x80\x81\n\n', '4.', '\xe8\xb5\xb7\xe6\xbb\xbe\xe6\xb0\xb4\xe9\x8d\x8b\xef\xbc\x8c\xe6\x94\xbe\xe5\x85\xa5\xe5\xb0\x91\xe8\xa8\xb1\xe9\xb9\xbd\xe5\xb7\xb4\xef\xbc\x8c\xe5\xb0\x87\xe6\xb0\xb4\xe9\xa4\x83\xe5\x85\xa5\xe9\x8d\x8b\xe7\x85\xae\xe7\x86\x9f\xef\xbc\x8c\n\xe5\x8d\xb3\xe5\x8f\xaf\xe7\x9b\x9b\xe8\xb5\xb7\xe6\x94\xbe\xe5\x9c\xa8\xe6\x88\x90\xe5\x93\x81\xe7\xa2\x97\xe4\xb8\xad\xef\xbc\x8c\xe6\xb7\x8b\xe4\xb8\x8a\xe5\xb0\x91\xe8\xa8\xb1\xe7\xb4\x85\xe6\xb2\xb9\xef\xbc\x8c\xe5\x82\x99\xe7\x94\xa8\xe3\x80\x82', '5.', '\xe8\xb5\xb7\xe9\x8d\x8b\x ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-11fd4096d566> in <module>()
#      13 #b = a.encode('utf-8')
#      14 print a.split(',')
# ---> 15 print b.split(',',1)
#      16 print b.split(',',2)
#
# NameError: name 'b' is not defined

# %%
#-*- coding: utf-8 -*-
a = '''2015.03.191967-3,

'''
#b = a.encode('utf-8')
print a.split(',')
print b.split(',',1)
print b.split(',',2)

help(a.split)
# Out:
# ['2015.03.191967-3', '\n\n']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-3cdaec706901> in <module>()
#       5 #b = a.encode('utf-8')
#       6 print a.split(',')
# ----> 7 print b.split(',',1)
#       8 print b.split(',',2)
#       9
#
# AttributeError: 'list' object has no attribute 'split'

# %%
tenderer_dic = {"廠商代碼":"tenderer_code", "廠商名稱":"tenderer_name", "是否得標":"awarded", "組織型態":"orgnization_type"} 
result_dic = {} 

tender_table = soup.find('table', { "class" : "table_block tender_table" }) 
award_table_tr_3 = tender_table.findAll( 'tr',{'class':'award_table_tr_3'})

import re 
m = re.match(r'投標廠商(?P<bidid>\d+)' ,'投標廠商10000') 
print m.group('bidid')
m = re.match(r'投標廠商(\d+)' ,'投標廠商101') 
print m.group(1)

a = ["投標廠商1", "1","11", "投標廠商2", "2","22"]
result = {}
current_vender_id = 0
for item in a:
    m = re.match("投標廠商(\d+)", item)
    print m
    if m: #== m is True
        current_vender_id = m.group(1)
        print current_vender_id
        result[current_vender_id] = {}
    else:
        result[current_vender_id] = item
print result
# Out:
# 10000
# 101
# <_sre.SRE_Match object at 0x1074f3468>
# 1
# None
# None
# <_sre.SRE_Match object at 0x1074f3468>
# 2
# None
# None
# {'1': '11', '2': '22'}

# %%
for tr in award_table_tr_3: 
    tb =tr.find('table') 
    grp_num = 0 
    if tb is not None: 
        row = tb.findAll('tr') 
        for r in row: 
            th = r.find('th').text 
            m = re.match(r'投標廠商(\d+)' ,th.encode('utf-8').strip()) 
            if m is not None: 
                grp_num = int(m.group(1)) 
                result_dic[grp_num] = {'tenderer_num': grp_num} 
            else: 
                if th.encode('utf-8').strip() in tenderer_dic: 
                    result_dic[grp_num][tenderer_dic[th.encode('utf-8').strip()]] = r.find('td').text.strip()
#print result_dic

for rec in result_dic:
    for i in  result_dic[rec]:
        print i, result_dic[rec][i]
# Out:
# tenderer_name 誠毅紙器股份有限公司
# orgnization_type 公司登記
# tenderer_code 75580992
# tenderer_num 1
# awarded 是
# tenderer_name 龍升印刷有限公司
# orgnization_type 公司登記
# tenderer_code 70489398
# tenderer_num 2
# awarded 否
# tenderer_name 龍宏印刷有限公司
# orgnization_type 公司登記
# tenderer_code 72205903
# tenderer_num 3
# awarded 否
# tenderer_name 捷采印刷事業股份有限公司
# orgnization_type 公司登記
# tenderer_code 23518409
# tenderer_num 4
# awarded 否
# tenderer_name 大暉彩色印刷有限公司
# orgnization_type 公司登記
# tenderer_code 22098203
# tenderer_num 5
# awarded 否

# %%
import re 
m = re.match( r"$?-?([0-9,]+)", '352,111元') 
print ''.join(m.group(1).split(','))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-60-8825b59962d0> in <module>()
#       1 import re
# ----> 2 m = re.match( r"$?-?([0-9,]+)", '352,111元')
#       3 print ''.join(m.group(1).split(','))
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/re.pyc in match(pattern, string, flags)
#     139     """Try to apply the pattern at the start of the string, returning
#     140     a match object, or None if no match was found."""
# --> 141     return _compile(pattern, flags).match(string)
#     142
#     143 def search(pattern, string, flags=0):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/re.pyc in _compile(*key)
#     249         p = sre_compile.compile(pattern, flags)
#     250     except error, v:
# --> 251         raise error, v # invalid expression
#     252     if not bypass_cache:
#     253         if len(_cache) >= _MAXCACHE:
#
# error: nothing to repeat

# %%
#-*- coding: utf-8 -*-
tender_award_dic = {"得標廠商":"awarded_tenderer", "預估需求數量":"request_number", "決標金額":"tender_awarding_value", "底價金額":"floor_price_value"}
#print tender_award_dic["得標廠商"]
a =  {"得標廠商":"IBM", "數量":50}
result = {}
for item in a:
    if item in tender_award_dic:
    print item
    print tender_award_dic[item].decode('unicode_escape')
# Out:
# 得標廠商
# awarded_tenderer
# 數量
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-6b725a341411> in <module>()
#       5 for item in a:
#       6     print item
# ----> 7     print tender_award_dic[item].decode('unicode_escape')
#
# KeyError: '\xe6\x95\xb8\xe9\x87\x8f'

# %%
award_dic = {}
tender_award_dic = {"得標廠商":"awarded_tenderer", "預估需求數量":"request_number", "決標金額":"tender_awarding_value", "底價金額":"floor_price_value"}
award_table_tr_4 = tender_table.findAll( 'tr',{'class':'award_table_tr_4'})		
for tr in award_table_tr_4:
	tb =tr.find('table')
	if tb is not None:
		row = tb.findAll('tr')
		item_num = 0
		grp_num = 0
		for r in row:
			if r.find('th') is not None:
				th = r.find('th').text
				#print r.find('th').text
				m = re.match(r'第(\d+)品項' ,th.encode('utf-8').strip())
				m2 = re.match(r'得標廠商(\d+)' ,th.encode('utf-8').strip())
				if m is not None:
					item_num =  int(m.group(1).decode('utf-8'))
					award_dic[item_num] = {}
				elif m2 is not None:
					grp_num =  int(m2.group(1).decode('utf-8'))
					award_dic[item_num][grp_num] = {}			
				else:
					if th.encode('utf-8').strip() in tender_award_dic:
						#print th.encode('utf-8').strip().decode('utf-8')
						if th.encode('utf-8').strip() == "決標金額" or th.encode('utf-8').strip() == "底價金額":
							m = re.match( r"\$?-?([0-9,]+)", "".join( r.find('td').text.split()))
							award_dic[item_num][grp_num][tender_award_dic[th.encode('utf-8').strip()]] =  int(''.join(m.group(0).split(',')))							
						else:
							award_dic[item_num][grp_num][tender_award_dic[th.encode('utf-8').strip()]] = r.find('td').text.strip()
#print award_dic

for rec in award_dic[1][1]:
    print rec, award_dic[1][1][rec]
# Out:
# request_number 5000
# awarded_tenderer 誠毅紙器股份有限公司

# %%
# -*- coding: utf-8 -*- 
from bs4 import BeautifulSoup 
from datetime import datetime 
import os, sys, re

def get_response_element (file_name): 
    f = open(file_name, 'r') 
    response_text = f.read() 
    f.close() 
    soup = BeautifulSoup(''.join(response_text)) 
    tender_table = soup.find('table', { "class" : "table_block tender_table" }) 
    print tender_table
    tr = tender_table.findAll('tr') 
    return tr

# %%
gettr = get_response_element("51081295_102-0400-1-051.txt")[0] #第一個tr
print gettr
# Out:
# <table border="1" cellpadding="0" cellspacing="0" class="table_block tender_table" width="100%">
# <caption style="display:none">
# <center>
# <font size="5">
#      決標公告
#     </font>
# </center>
# <div align="center" id="printAwardDate" style="display:block">
#     公告日:102/10/18
#    </div>
# </caption>
# <tbody>
# <tr>
# <td align="center" colspan="4" style="border:1px solid #FFFFFF;">
# <center>
# <h1>
#        決標公告
#       </h1>
# </center>
# <div align="center" id="printAwardDate" style="display:block">
# <h3>
#        公告日:102/10/18
#       </h3>
# </div>
# <div class="remind_msg">
# </div>
# </td>
# </tr>
# <!-- delimiter 機關資料 Start -->
# <tr class="award_table_tr_1">
# <td align="center" bgcolor="#89C0C7" class="style1" rowspan="8" valign="middle" width="38">
# <span class="newstop">
#       機
#       <br/>
#       關
#       <br/>
#       資
#       <br/>
#       料
#      </span>
# </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">
#      機關代碼
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      3.7.74.37
#     </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">
#      機關名稱
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      臺灣菸酒股份有限公司隆田酒廠
#     </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">
#      單位名稱
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      臺灣菸酒股份有限公司隆田酒廠
#     </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">
#      機關地址
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      720臺南市官田區隆本里中華路一段335號
#     </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">
#      聯絡人
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      張淑英
#     </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">
#      聯絡電話
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      (06)5791311 分機 431
#     </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" style="height: 25px" valign="middle" width="200">
#      傳真號碼
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      (06)5793581
#     </td>
# </tr>
# <!-- delimiter 機關資料 End -->
# <!-- delimiter 已公告/採購資料 Start -->
# <tr class="award_table_tr_2">
# <td align="center" bgcolor="#FCD847" class="form_head" rowspan="26 " valign="middle" width="38">
# <span class="newstop">
#       已
#       <br/>
#       公
#       <br/>
#       告
#       <br/>
#       資
#       <br/>
#       料
#      </span>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      標案案號
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      102-0400-1-051
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      招標方式
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      公開取得報價單或企劃書
#      <div class="remind_msg">
# </div>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      決標方式
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      最低標
#      <div class="remind_msg">
# </div>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否依「機關異質採購
#      <br>
#       最低標作業須知」辦理
#      </br>
# </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#      <div class="remind_msg">
# </div>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      新增公告傳輸次數
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      02
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      標案名稱
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      5.4公升蟲草養生酒彩盒5,000個
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      決標資料類別
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      決標公告
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否屬共同供應契約採購
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否複數決標
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否共同投標
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      標的分類
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      &lt;財物類&gt;
#                             32
#                             紙漿,紙及紙產品;印刷品及相關的商品
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否屬統包
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否應依公共工程專業技師簽證規則實施技師簽證
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      開標時間
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      102/10/14 15:00
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      原公告日期
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      102/10/08
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      採購金額級距
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      未達公告金額
#      <div class="remind_msg">
# </div>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      辦理方式
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      自辦
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      預算金額是否公開
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否受機關補助
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      履約地點
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      臺南市(非原住民地區)
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      履約地點（含地區）
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      臺南市－官田區
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否屬優先採購身心障礙福利機構產品或勞務
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否含特別預算
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      歸屬計畫類別
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      非屬愛台十二項計畫
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      本案採購契約是否採用主管機關訂定之範本
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      是
#     </td>
# </tr>
# <!-- 不公開於廠商端/民眾端及政府採購公報 -->
# <!-- delimiter 已公告/採購資料 End -->
# <!-- delimiter 資訊服務價格 Start -->
# <!-- delimiter 資訊服務價格 End -->
# <!-- delimiter 投標廠商 Start -->
# <tr class="award_table_tr_3">
# <td align="center" bgcolor="#F5BF65" rowspan="2" valign="middle" width="38">
# <span class="newstop">
#       投
#       <br/>
#       標
#       <br/>
#       廠
#       <br/>
#       商
#      </span>
# </td>
# </tr>
# <tr class="award_table_tr_3">
# <td colspan="3" style="padding-top:0px; padding-bottom:0px; padding-right:0px; padding-left:0px;">
# <table bgcolor="#F5BF65" border="1" bordercolor="#F5BF65" cellpadding="1" cellspacing="1" class="table_block tender_table" height="100%" style="border-collapse:collapse;" summary="*" width="100%">
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         投標廠商家數
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         5
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         投標廠商1
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商代碼
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         75580992
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商名稱
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         誠毅紙器股份有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         是否得標
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         組織型態
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
#         公司登記
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商業別
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
#         其他
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商地址
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         814高雄市仁武區新庄路15號
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商電話
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         (07)
#
#
# 				3715126
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         得標廠商國別
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         中華民國(Republic of China (Taiwan))
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         是否為中小企業
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         履約起迄日期
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         102/10/15－102/11/03
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         雇用員工總人數是否
#         <br>
#          超過100人
#         </br>
# </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         僱用員工總
#         <br>
#          人數
#         </br>
# </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         310
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         已僱用原住民
#         <br>
#          人數
#         </br>
# </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         6
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         已僱用身心障礙者
#         <br>
#          人數
#         </br>
# </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         4
#        </td>
# </tr>
# <!-- isEmployeeOver100 -->
# <!-- isObtain -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         投標廠商2
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商代碼
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         70489398
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商名稱
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         龍升印刷有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         是否得標
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         否
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         組織型態
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
#         公司登記
#        </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         投標廠商3
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商代碼
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         72205903
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商名稱
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         龍宏印刷有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         是否得標
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         否
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         組織型態
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
#         公司登記
#        </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         投標廠商4
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商代碼
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         23518409
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商名稱
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         捷采印刷事業股份有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         是否得標
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         否
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         組織型態
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
#         公司登記
#        </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         投標廠商5
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商代碼
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         22098203
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商名稱
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         大暉彩色印刷有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         是否得標
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         否
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         組織型態
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
#         公司登記
#        </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# </table>
# </td>
# </tr>
# <!-- delimiter 投標廠商 End -->
# <!-- delimiter 簽約廠商 Start -->
# <!-- delimiter 簽約廠商 End -->
# <!-- delimiter 決標品項 Start -->
# <tr class="award_table_tr_4">
# <td align="center" bgcolor="#FF9999" rowspan="2" valign="middle" width="38">
# <span class="newstop">
#       決
#       <br/>
#       標
#       <br/>
#       品
#       <br/>
#       項
#      </span>
# </td>
# </tr>
# <tr class="award_table_tr_4">
# <td colspan="3" style="padding-top:0px; padding-bottom:0px; padding-right:0px; padding-left:0px;">
# <table bgcolor="#FF9999" border="1" bordercolor="#FF9999" cellpadding="1" cellspacing="1" class="table_block tender_table" height="100%" style="border-collapse:collapse;" summary="*" width="100%">
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         決標品項數
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         1
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         第1品項
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         品項名稱
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         5.4公升蟲草養生酒彩盒5,000個
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         是否以單價及預估需
#         <br>
#          求數量之乘積決定最
#          <br>
#           低標
#          </br>
# </br>
# </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         否
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         得標廠商1
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         得標廠商
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         誠毅紙器股份有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         預估需求數量
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         5000
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         原產地國別
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# <table border="0" cellpadding="0" cellspacing="1" class="shift" id="table_ob_nation">
# <tr>
# <td class="newstop" width="100px">
#            原產地國別
#           </td>
# <td class="newstop">
#            中華民國(Republic of China (Taiwan))
#           </td>
# </tr>
# <tr>
# <td class="newstop" colspan="2">
# <hr/>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商1
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         龍升印刷有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         是否合格
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標原因
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         資格、規格合於招標文件但非最低(高)標
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         標價偏低理由
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商2
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         龍宏印刷有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         是否合格
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標原因
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         資格、規格合於招標文件但非最低(高)標
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         標價偏低理由
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商3
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         捷采印刷事業股份有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         是否合格
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標原因
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         資格、規格合於招標文件但非最低(高)標
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         標價偏低理由
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商4
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         大暉彩色印刷有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         是否合格
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標原因
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         資格、規格合於招標文件但非最低(高)標
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         標價偏低理由
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# </table>
# </td>
# </tr>
# <!-- delimiter 決標品項 End -->
# <!-- delimiter 最有利標 Start -->
# <!-- delimiter 最有利標 End -->
# <!-- delimiter 英文公告 Start -->
# <!-- delimiter 英文公告 End -->
# <!-- delimiter 決標資料 Start -->
# <tr class="award_table_tr_6">
# <td align="center" bgcolor="#c79961" class="form_head" rowspan="11" valign="middle" width="38">
# <span class="newstop">
#       決
#       <br/>
#       標
#       <br/>
#       資
#       <br/>
#       料
#      </span>
# </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      決標公告序號
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      001
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      決標日期
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      102/10/14
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      決標公告日期
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      102/10/18
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      是否刊登公報
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      底價金額是否公開
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      總決標金額是否公開
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <!-- 最低標標案才顯示是否依採購法第58條規定採次低標或次次低標決標 -->
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      契約是否訂有依物價指數調整價金規定
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      未列物價調整規定說明
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      財物案
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      履約執行機關
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      機關代碼：3.7.74.37
#      <br>
#       機關名稱：臺灣菸酒股份有限公司隆田酒廠
#      </br>
# </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      附加說明
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <!-- delimiter 決標資料 End -->
# <!-- delimiter 撤銷公告 Start -->
# <!-- delimiter 撤銷公告 End -->
# </tbody>
# </table>
# <tr>
# <td align="center" colspan="4" style="border:1px solid #FFFFFF;">
# <center>
# <h1>
#        決標公告
#       </h1>
# </center>
# <div align="center" id="printAwardDate" style="display:block">
# <h3>
#        公告日:102/10/18
#       </h3>
# </div>
# <div class="remind_msg">
# </div>
# </td>
# </tr>

# %%
def date_conversion(element):
        m = re.match(r"(\d+/\d+/\d+)",element)
        if m is not None:
                t = m.group(1).split('/', 1)
                if t[0] != '':
                        return datetime.strptime(str(int(t[0]) + 1911) + "/" + (''.join(t[1:]).split()[0] ), "%Y/%m/%d")
        else:
                return None

# %%
print date_conversion("103/3/23")
# Out:
# 2014-03-23 00:00:00

# %%
def money_conversion(element): 
    m = re.match( r"\$?-?([0-9,]+)", "".join(element.split())) 
    return int(''.join(m.group(1).split(',')))

# %%
print money_conversion("2,350,000元")+1000
print money_conversion("-2,350,000")+1000
print money_conversion("$2,350,000")
# Out:
# 2351000
# 2351000
# 2350000

# %%
def remove_space(element): 
    return "".join(element.split())

# %%
tender_awards_map = {"機關代碼":remove_space, "機關名稱":remove_space}
a = {"機關代碼": '234242 23424 2423020230' }
print tender_awards_map["機關代碼"](a["機關代碼"])
# Out:
# 234242234242423020230

# %%
name_map = {"機關代碼":"entity_code", "機關名稱":"procuring_entity","標案案號":"job_number","招標方式":"procurement_type",\
    "決標方式":"tender_awarding_type","標案名稱":"subject_of_procurement", "決標資料類別":"attr_of_tender_awarding", \
    "標的分類":"attr_of_procurement", "預算金額":"budget_value", "開標時間":"opening_date","決標公告日期":"tender_awarding_announce_date",\
    "歸屬計畫類別":"project_type","總決標金額":"total_tender_awarding_value","底價金額":"floor_price_value","決標日期":"tender_awarding_date", "pkAtmMain":"pkAtmMain"}

tender_awards_map = {"機關代碼":remove_space, "機關名稱":remove_space, "標案案號":remove_space, \
    "招標方式":remove_space,"決標方式":remove_space,"標案名稱":remove_space, "決標資料類別":remove_space, \
    "標的分類":remove_space, "預算金額":money_conversion, "開標時間":date_conversion,"歸屬計畫類別":remove_space, \
    "總決標金額":money_conversion,"底價金額":money_conversion,"決標日期":date_conversion, "決標公告日期":date_conversion}

tender_award_item_map = {"得標廠商":"awarded_tenderer", "預估需求數量":"request_number", "決標金額":"tender_awarding_value", "底價金額":"floor_price_value"}
tenderer_map = {"廠商代碼":"tenderer_code", "廠商名稱":"tenderer_name", "是否得標":"awarded", "組織型態":"orgnization_type"}

# %%
def get_award_info_dic (element):
	returned_dic = {}
	for row in element:
		th = row.find('th')
		if th is not None and row.get('class') is not None:
		    th_name = th.text.encode('utf-8').strip()
		    if ('award_table_tr_1' or 'award_table_tr_2' or  'award_table_tr_6'  in row.get('class')) and  (th_name in  tender_awards_map):
		        returned_dic[name_map[th_name]]   =   tender_awards_map[th_name](row.find('td').text.strip())
	return returned_dic

# %%
gettr = get_response_element('51081295_102-0400-1-051.txt')
aid =  get_award_info_dic(gettr)
for ent in aid:
    print ent, aid[ent]
# Out:
# <table border="1" cellpadding="0" cellspacing="0" class="table_block tender_table" width="100%">
# <caption style="display:none">
# <center>
# <font size="5">
#      決標公告
#     </font>
# </center>
# <div align="center" id="printAwardDate" style="display:block">
#     公告日:102/10/18
#    </div>
# </caption>
# <tbody>
# <tr>
# <td align="center" colspan="4" style="border:1px solid #FFFFFF;">
# <center>
# <h1>
#        決標公告
#       </h1>
# </center>
# <div align="center" id="printAwardDate" style="display:block">
# <h3>
#        公告日:102/10/18
#       </h3>
# </div>
# <div class="remind_msg">
# </div>
# </td>
# </tr>
# <!-- delimiter 機關資料 Start -->
# <tr class="award_table_tr_1">
# <td align="center" bgcolor="#89C0C7" class="style1" rowspan="8" valign="middle" width="38">
# <span class="newstop">
#       機
#       <br/>
#       關
#       <br/>
#       資
#       <br/>
#       料
#      </span>
# </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">
#      機關代碼
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      3.7.74.37
#     </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">
#      機關名稱
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      臺灣菸酒股份有限公司隆田酒廠
#     </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">
#      單位名稱
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      臺灣菸酒股份有限公司隆田酒廠
#     </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">
#      機關地址
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      720臺南市官田區隆本里中華路一段335號
#     </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">
#      聯絡人
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      張淑英
#     </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">
#      聯絡電話
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      (06)5791311 分機 431
#     </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" style="height: 25px" valign="middle" width="200">
#      傳真號碼
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      (06)5793581
#     </td>
# </tr>
# <!-- delimiter 機關資料 End -->
# <!-- delimiter 已公告/採購資料 Start -->
# <tr class="award_table_tr_2">
# <td align="center" bgcolor="#FCD847" class="form_head" rowspan="26 " valign="middle" width="38">
# <span class="newstop">
#       已
#       <br/>
#       公
#       <br/>
#       告
#       <br/>
#       資
#       <br/>
#       料
#      </span>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      標案案號
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      102-0400-1-051
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      招標方式
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      公開取得報價單或企劃書
#      <div class="remind_msg">
# </div>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      決標方式
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      最低標
#      <div class="remind_msg">
# </div>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否依「機關異質採購
#      <br>
#       最低標作業須知」辦理
#      </br>
# </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#      <div class="remind_msg">
# </div>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      新增公告傳輸次數
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      02
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      標案名稱
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      5.4公升蟲草養生酒彩盒5,000個
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      決標資料類別
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      決標公告
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否屬共同供應契約採購
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否複數決標
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否共同投標
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      標的分類
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      &lt;財物類&gt;
#                             32
#                             紙漿,紙及紙產品;印刷品及相關的商品
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否屬統包
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否應依公共工程專業技師簽證規則實施技師簽證
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      開標時間
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      102/10/14 15:00
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      原公告日期
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      102/10/08
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      採購金額級距
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      未達公告金額
#      <div class="remind_msg">
# </div>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      辦理方式
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      自辦
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      預算金額是否公開
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否受機關補助
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      履約地點
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      臺南市(非原住民地區)
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      履約地點（含地區）
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      臺南市－官田區
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否屬優先採購身心障礙福利機構產品或勞務
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否含特別預算
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      歸屬計畫類別
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      非屬愛台十二項計畫
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      本案採購契約是否採用主管機關訂定之範本
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      是
#     </td>
# </tr>
# <!-- 不公開於廠商端/民眾端及政府採購公報 -->
# <!-- delimiter 已公告/採購資料 End -->
# <!-- delimiter 資訊服務價格 Start -->
# <!-- delimiter 資訊服務價格 End -->
# <!-- delimiter 投標廠商 Start -->
# <tr class="award_table_tr_3">
# <td align="center" bgcolor="#F5BF65" rowspan="2" valign="middle" width="38">
# <span class="newstop">
#       投
#       <br/>
#       標
#       <br/>
#       廠
#       <br/>
#       商
#      </span>
# </td>
# </tr>
# <tr class="award_table_tr_3">
# <td colspan="3" style="padding-top:0px; padding-bottom:0px; padding-right:0px; padding-left:0px;">
# <table bgcolor="#F5BF65" border="1" bordercolor="#F5BF65" cellpadding="1" cellspacing="1" class="table_block tender_table" height="100%" style="border-collapse:collapse;" summary="*" width="100%">
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         投標廠商家數
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         5
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         投標廠商1
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商代碼
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         75580992
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商名稱
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         誠毅紙器股份有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         是否得標
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         組織型態
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
#         公司登記
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商業別
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
#         其他
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商地址
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         814高雄市仁武區新庄路15號
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商電話
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         (07)
#
#
# 				3715126
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         得標廠商國別
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         中華民國(Republic of China (Taiwan))
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         是否為中小企業
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         履約起迄日期
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         102/10/15－102/11/03
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         雇用員工總人數是否
#         <br>
#          超過100人
#         </br>
# </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         僱用員工總
#         <br>
#          人數
#         </br>
# </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         310
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         已僱用原住民
#         <br>
#          人數
#         </br>
# </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         6
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         已僱用身心障礙者
#         <br>
#          人數
#         </br>
# </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         4
#        </td>
# </tr>
# <!-- isEmployeeOver100 -->
# <!-- isObtain -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         投標廠商2
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商代碼
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         70489398
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商名稱
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         龍升印刷有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         是否得標
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         否
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         組織型態
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
#         公司登記
#        </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         投標廠商3
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商代碼
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         72205903
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商名稱
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         龍宏印刷有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         是否得標
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         否
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         組織型態
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
#         公司登記
#        </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         投標廠商4
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商代碼
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         23518409
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商名稱
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         捷采印刷事業股份有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         是否得標
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         否
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         組織型態
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
#         公司登記
#        </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         投標廠商5
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商代碼
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         22098203
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商名稱
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         大暉彩色印刷有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         是否得標
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         否
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         組織型態
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
#         公司登記
#        </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# </table>
# </td>
# </tr>
# <!-- delimiter 投標廠商 End -->
# <!-- delimiter 簽約廠商 Start -->
# <!-- delimiter 簽約廠商 End -->
# <!-- delimiter 決標品項 Start -->
# <tr class="award_table_tr_4">
# <td align="center" bgcolor="#FF9999" rowspan="2" valign="middle" width="38">
# <span class="newstop">
#       決
#       <br/>
#       標
#       <br/>
#       品
#       <br/>
#       項
#      </span>
# </td>
# </tr>
# <tr class="award_table_tr_4">
# <td colspan="3" style="padding-top:0px; padding-bottom:0px; padding-right:0px; padding-left:0px;">
# <table bgcolor="#FF9999" border="1" bordercolor="#FF9999" cellpadding="1" cellspacing="1" class="table_block tender_table" height="100%" style="border-collapse:collapse;" summary="*" width="100%">
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         決標品項數
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         1
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         第1品項
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         品項名稱
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         5.4公升蟲草養生酒彩盒5,000個
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         是否以單價及預估需
#         <br>
#          求數量之乘積決定最
#          <br>
#           低標
#          </br>
# </br>
# </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         否
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         得標廠商1
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         得標廠商
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         誠毅紙器股份有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         預估需求數量
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         5000
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         原產地國別
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# <table border="0" cellpadding="0" cellspacing="1" class="shift" id="table_ob_nation">
# <tr>
# <td class="newstop" width="100px">
#            原產地國別
#           </td>
# <td class="newstop">
#            中華民國(Republic of China (Taiwan))
#           </td>
# </tr>
# <tr>
# <td class="newstop" colspan="2">
# <hr/>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商1
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         龍升印刷有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         是否合格
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標原因
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         資格、規格合於招標文件但非最低(高)標
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         標價偏低理由
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商2
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         龍宏印刷有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         是否合格
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標原因
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         資格、規格合於招標文件但非最低(高)標
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         標價偏低理由
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商3
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         捷采印刷事業股份有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         是否合格
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標原因
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         資格、規格合於招標文件但非最低(高)標
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         標價偏低理由
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商4
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         大暉彩色印刷有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         是否合格
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標原因
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         資格、規格合於招標文件但非最低(高)標
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         標價偏低理由
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# </table>
# </td>
# </tr>
# <!-- delimiter 決標品項 End -->
# <!-- delimiter 最有利標 Start -->
# <!-- delimiter 最有利標 End -->
# <!-- delimiter 英文公告 Start -->
# <!-- delimiter 英文公告 End -->
# <!-- delimiter 決標資料 Start -->
# <tr class="award_table_tr_6">
# <td align="center" bgcolor="#c79961" class="form_head" rowspan="11" valign="middle" width="38">
# <span class="newstop">
#       決
#       <br/>
#       標
#       <br/>
#       資
#       <br/>
#       料
#      </span>
# </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      決標公告序號
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      001
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      決標日期
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      102/10/14
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      決標公告日期
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      102/10/18
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      是否刊登公報
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      底價金額是否公開
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      總決標金額是否公開
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <!-- 最低標標案才顯示是否依採購法第58條規定採次低標或次次低標決標 -->
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      契約是否訂有依物價指數調整價金規定
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      未列物價調整規定說明
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      財物案
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      履約執行機關
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      機關代碼：3.7.74.37
#      <br>
#       機關名稱：臺灣菸酒股份有限公司隆田酒廠
#      </br>
# </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      附加說明
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <!-- delimiter 決標資料 End -->
# <!-- delimiter 撤銷公告 Start -->
# <!-- delimiter 撤銷公告 End -->
# </tbody>
# </table>
# entity_code 3.7.74.37
# procuring_entity 臺灣菸酒股份有限公司隆田酒廠

# %%
def get_tender_award_item_dic (element):
	returned_dic = {}
	item_num = 0
	grp_num = 0
	for tr in element:
		if tr.get('class') is not None and tr.get('class')[0] == 'award_table_tr_4' and tr.find('table') is not None:
			row = tr.find('table').findAll('tr')
			for r in row:
				if r.find('th') is not None:
					th = r.find('th').text.encode('utf-8').strip()
					m = re.match(r'第(\d+)品項' ,th)
					m2 = re.match(r'得標廠商(\d+)' ,th)
					if m is not None:
						item_num =  int(m.group(1).decode('utf-8'))
						returned_dic[item_num] = {}
					elif m2 is not None:
						grp_num =  int(m2.group(1).decode('utf-8'))
						returned_dic[item_num][grp_num] = {}			
					else:
						if th in tender_award_item_map:
							if th == "決標金額" or th == "底價金額":
								returned_dic[item_num][grp_num][tender_award_item_map[th]] = money_conversion(r.find('td').text) 							
							else:
								returned_dic[item_num][grp_num][tender_award_item_map[th]] = r.find('td').text.strip()
	return returned_dic

# %%
import sqlite3 as lite 
import sys 
con = None 
dbname = 'nsb.sqlite'
try: 
    con = lite.connect(dbname) # connect to database 
    cur = con.cursor() # create cursor 
    cur.execute('SELECT SQLITE_VERSION()') # selece database version  
    data = cur.fetchone() # fetch one data at a time 
    print "SQLite version: %s" % data 
except lite.Error, e: 
    print "Error %s:" % e.args[0] 
    sys.exit(1) 
finally: 
    if con: 
        con.close()
# Out:
# SQLite version: 3.8.3.1

# %%
import sqlite3 as lite 
import sys 
con = lite.connect("test.db") 
with con: 
    cur = con.cursor() # Drop Table If Exisits 
    cur.execute("DROP TABLE IF EXISTS PhoneAddress") 
    cur.execute("CREATE TABLE PhoneAddress(phone CHAR(10) PRIMARY KEY, address TEXT, name TEXT unique, age INT NOT NULL)") 
    cur.execute("INSERT INTO PhoneAddress VALUES('0912173381','United State','Jhon Doe',53)") 
    cur.execute("INSERT INTO PhoneAddress VALUES('0928375018','Tokyo Japan','MuMu Cat',6)") 
    cur.execute("INSERT INTO PhoneAddress VALUES('0957209108','Taipei','Richard',29)") 
    cur.execute("SELECT phone,address, name FROM PhoneAddress") 
    data = cur.fetchall() 
    for rec in data: 
        print rec[0], rec[1], rec[2] 
con.close()
# Out:
# 0912173381 United State Jhon Doe
# 0928375018 Tokyo Japan MuMu Cat
# 0957209108 Taipei Richard

# %%
import sqlite3 as lite 
import sys 
con = lite.connect("test.db") 
with con:
    
    cur = con.cursor()
    # Read Meta Information
    cur.execute("PRAGMA table_info(PhoneAddress)")    
    rows = cur.fetchall()#是tuple型態
    for row in rows:
        print row
    
con.close()
# Out:
# (0, u'phone', u'CHAR(10)', 0, None, 1)
# (1, u'address', u'TEXT', 0, None, 0)
# (2, u'name', u'TEXT', 0, None, 0)
# (3, u'age', u'INT', 1, None, 0)

# %%
import sqlite3 as lite 
import sys 
con = lite.connect("test.db") 
with con: 
    cur = con.cursor() # Drop Table If Exisits 
    cur.execute("SELECT phone,address FROM PhoneAddress") 
    data = cur.fetchone() 
    print data[0], data[1] 
    data1 = cur.fetchone() 
    print data1[0], data1[1] 
con.close()
# Out:
# 0912173381 United State
# 0928375018 Tokyo Japan

# %%
import sqlite3 as lite 
import sys 
con = lite.connect("test.db") 
with con: 
    cur = con.cursor() # Drop Table If Exisits 
    cur.execute("SELECT phone,address FROM PhoneAddress")
    data = cur.fetchone() 
    print data[0], data[1] 
    rows = cur.fetchall()
    for row in rows:
        print row

con.close()
# Out:
# 0912173381 United State
# (u'0928375018', u'Tokyo Japan')
# (u'0957209108', u'Taipei')

# %%
# -*- coding: utf-8 -*- 
import sqlite3

db = sqlite3.connect('tender.db') 
cur = db.cursor()

# %%
cur.execute('''CREATE TABLE IF NOT EXISTS Tender_awards(
                id INTEGER PRIMARY KEY,
                pkAtmMain TEXT,
                procuring_entity TEXT,
                entity_code TEXT,
                attr_of_procurement TEXT,
                opening_date DATETIME,
                procurement_type TEXT,
                tender_awarding_type TEXT,
                project_type TEXT,
                subject_of_procurement TEXT,
                job_number TEXT,
                budget_value BIGINTEGER,
                attr_of_tender_awarding TEXT,
                floor_price_value BIGINTEGER,
                tender_awarding_announce_date DATETIME,
                tender_awarding_date DATETIME,
                total_tender_awarding_value BIGINTEGER
                )''')

# %%
cur.execute('''CREATE TABLE IF NOT EXISTS Tenderer(
    id INTEGER PRIMARY KEY,
    pkAtmMain TEXT,
    job_number TEXT,
    tenderer_code TEXT,
    tenderer_name TEXT,                
    awarded TEXT,
    orgnization_type TEXT,
    tenderer_num INT
    )''')

# %%
cur.execute('''CREATE TABLE IF NOT EXISTS Tender_award_item(
    id INTEGER PRIMARY KEY,
    pkAtmMain TEXT,
    job_number TEXT,
    awarded_tenderer TEXT,
    request_number INT,                
    tender_awarding_value BIGINT,
    floor_price_value BIGINT,
    item_num INT,
    awarded_num INT
    )''')

# %%
ele = get_response_element('51081295_102-0400-1-051.txt') 
award_info_dic = get_award_info_dic(ele) 
tenderer_info_dic = get_tenderer_info_dic(ele) 
tender_award_item_dic = get_tender_award_item_dic(ele)

print award_info_dic
print tenderer_info_dic 
print tender_award_item_dic
# Out:
# <table border="1" cellpadding="0" cellspacing="0" class="table_block tender_table" width="100%">
# <caption style="display:none">
# <center>
# <font size="5">
#      決標公告
#     </font>
# </center>
# <div align="center" id="printAwardDate" style="display:block">
#     公告日:102/10/18
#    </div>
# </caption>
# <tbody>
# <tr>
# <td align="center" colspan="4" style="border:1px solid #FFFFFF;">
# <center>
# <h1>
#        決標公告
#       </h1>
# </center>
# <div align="center" id="printAwardDate" style="display:block">
# <h3>
#        公告日:102/10/18
#       </h3>
# </div>
# <div class="remind_msg">
# </div>
# </td>
# </tr>
# <!-- delimiter 機關資料 Start -->
# <tr class="award_table_tr_1">
# <td align="center" bgcolor="#89C0C7" class="style1" rowspan="8" valign="middle" width="38">
# <span class="newstop">
#       機
#       <br/>
#       關
#       <br/>
#       資
#       <br/>
#       料
#      </span>
# </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">
#      機關代碼
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      3.7.74.37
#     </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">
#      機關名稱
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      臺灣菸酒股份有限公司隆田酒廠
#     </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">
#      單位名稱
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      臺灣菸酒股份有限公司隆田酒廠
#     </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">
#      機關地址
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      720臺南市官田區隆本里中華路一段335號
#     </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">
#      聯絡人
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      張淑英
#     </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">
#      聯絡電話
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      (06)5791311 分機 431
#     </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" style="height: 25px" valign="middle" width="200">
#      傳真號碼
#     </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#      (06)5793581
#     </td>
# </tr>
# <!-- delimiter 機關資料 End -->
# <!-- delimiter 已公告/採購資料 Start -->
# <tr class="award_table_tr_2">
# <td align="center" bgcolor="#FCD847" class="form_head" rowspan="26 " valign="middle" width="38">
# <span class="newstop">
#       已
#       <br/>
#       公
#       <br/>
#       告
#       <br/>
#       資
#       <br/>
#       料
#      </span>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      標案案號
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      102-0400-1-051
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      招標方式
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      公開取得報價單或企劃書
#      <div class="remind_msg">
# </div>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      決標方式
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      最低標
#      <div class="remind_msg">
# </div>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否依「機關異質採購
#      <br>
#       最低標作業須知」辦理
#      </br>
# </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#      <div class="remind_msg">
# </div>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      新增公告傳輸次數
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      02
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      標案名稱
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      5.4公升蟲草養生酒彩盒5,000個
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      決標資料類別
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      決標公告
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否屬共同供應契約採購
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否複數決標
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否共同投標
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      標的分類
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      &lt;財物類&gt;
#                             32
#                             紙漿,紙及紙產品;印刷品及相關的商品
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否屬統包
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否應依公共工程專業技師簽證規則實施技師簽證
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      開標時間
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      102/10/14 15:00
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      原公告日期
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      102/10/08
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      採購金額級距
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      未達公告金額
#      <div class="remind_msg">
# </div>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      辦理方式
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      自辦
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      預算金額是否公開
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否受機關補助
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      履約地點
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      臺南市(非原住民地區)
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      履約地點（含地區）
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      臺南市－官田區
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否屬優先採購身心障礙福利機構產品或勞務
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      是否含特別預算
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      歸屬計畫類別
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      非屬愛台十二項計畫
#     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">
#      本案採購契約是否採用主管機關訂定之範本
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      是
#     </td>
# </tr>
# <!-- 不公開於廠商端/民眾端及政府採購公報 -->
# <!-- delimiter 已公告/採購資料 End -->
# <!-- delimiter 資訊服務價格 Start -->
# <!-- delimiter 資訊服務價格 End -->
# <!-- delimiter 投標廠商 Start -->
# <tr class="award_table_tr_3">
# <td align="center" bgcolor="#F5BF65" rowspan="2" valign="middle" width="38">
# <span class="newstop">
#       投
#       <br/>
#       標
#       <br/>
#       廠
#       <br/>
#       商
#      </span>
# </td>
# </tr>
# <tr class="award_table_tr_3">
# <td colspan="3" style="padding-top:0px; padding-bottom:0px; padding-right:0px; padding-left:0px;">
# <table bgcolor="#F5BF65" border="1" bordercolor="#F5BF65" cellpadding="1" cellspacing="1" class="table_block tender_table" height="100%" style="border-collapse:collapse;" summary="*" width="100%">
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         投標廠商家數
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         5
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         投標廠商1
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商代碼
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         75580992
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商名稱
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         誠毅紙器股份有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         是否得標
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         組織型態
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
#         公司登記
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商業別
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
#         其他
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商地址
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         814高雄市仁武區新庄路15號
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商電話
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         (07)
#
#
# 				3715126
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         得標廠商國別
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         中華民國(Republic of China (Taiwan))
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         是否為中小企業
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         履約起迄日期
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         102/10/15－102/11/03
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         雇用員工總人數是否
#         <br>
#          超過100人
#         </br>
# </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         僱用員工總
#         <br>
#          人數
#         </br>
# </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         310
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         已僱用原住民
#         <br>
#          人數
#         </br>
# </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         6
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         已僱用身心障礙者
#         <br>
#          人數
#         </br>
# </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         4
#        </td>
# </tr>
# <!-- isEmployeeOver100 -->
# <!-- isObtain -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         投標廠商2
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商代碼
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         70489398
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商名稱
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         龍升印刷有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         是否得標
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         否
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         組織型態
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
#         公司登記
#        </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         投標廠商3
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商代碼
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         72205903
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商名稱
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         龍宏印刷有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         是否得標
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         否
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         組織型態
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
#         公司登記
#        </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         投標廠商4
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商代碼
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         23518409
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商名稱
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         捷采印刷事業股份有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         是否得標
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         否
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         組織型態
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
#         公司登記
#        </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         投標廠商5
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商代碼
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#         22098203
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         廠商名稱
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         大暉彩色印刷有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         是否得標
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         否
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#ffdd83" class="T11b" valign="middle" width="200">
#         組織型態
#        </th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
#         公司登記
#        </td>
# </tr>
# <!-- isObtain -->
# <!-- isNotObtain start -->
# <!-- isNotObtain end -->
# </table>
# </td>
# </tr>
# <!-- delimiter 投標廠商 End -->
# <!-- delimiter 簽約廠商 Start -->
# <!-- delimiter 簽約廠商 End -->
# <!-- delimiter 決標品項 Start -->
# <tr class="award_table_tr_4">
# <td align="center" bgcolor="#FF9999" rowspan="2" valign="middle" width="38">
# <span class="newstop">
#       決
#       <br/>
#       標
#       <br/>
#       品
#       <br/>
#       項
#      </span>
# </td>
# </tr>
# <tr class="award_table_tr_4">
# <td colspan="3" style="padding-top:0px; padding-bottom:0px; padding-right:0px; padding-left:0px;">
# <table bgcolor="#FF9999" border="1" bordercolor="#FF9999" cellpadding="1" cellspacing="1" class="table_block tender_table" height="100%" style="border-collapse:collapse;" summary="*" width="100%">
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         決標品項數
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         1
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         第1品項
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         品項名稱
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         5.4公升蟲草養生酒彩盒5,000個
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         是否以單價及預估需
#         <br>
#          求數量之乘積決定最
#          <br>
#           低標
#          </br>
# </br>
# </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         否
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         得標廠商1
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         得標廠商
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         誠毅紙器股份有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         預估需求數量
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         5000
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         原產地國別
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# <table border="0" cellpadding="0" cellspacing="1" class="shift" id="table_ob_nation">
# <tr>
# <td class="newstop" width="100px">
#            原產地國別
#           </td>
# <td class="newstop">
#            中華民國(Republic of China (Taiwan))
#           </td>
# </tr>
# <tr>
# <td class="newstop" colspan="2">
# <hr/>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商1
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         龍升印刷有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         是否合格
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標原因
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         資格、規格合於招標文件但非最低(高)標
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         標價偏低理由
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商2
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         龍宏印刷有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         是否合格
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標原因
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         資格、規格合於招標文件但非最低(高)標
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         標價偏低理由
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商3
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         捷采印刷事業股份有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         是否合格
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標原因
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         資格、規格合於招標文件但非最低(高)標
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         標價偏低理由
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商4
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標廠商
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         大暉彩色印刷有限公司
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         是否合格
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         是
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         未得標原因
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
#         資格、規格合於招標文件但非最低(高)標
#        </td>
# </tr>
# <tr>
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">
#         標價偏低理由
#        </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# </table>
# </td>
# </tr>
# <!-- delimiter 決標品項 End -->
# <!-- delimiter 最有利標 Start -->
# <!-- delimiter 最有利標 End -->
# <!-- delimiter 英文公告 Start -->
# <!-- delimiter 英文公告 End -->
# <!-- delimiter 決標資料 Start -->
# <tr class="award_table_tr_6">
# <td align="center" bgcolor="#c79961" class="form_head" rowspan="11" valign="middle" width="38">
# <span class="newstop">
#       決
#       <br/>
#       標
#       <br/>
#       資
#       <br/>
#       料
#      </span>
# </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      決標公告序號
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      001
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      決標日期
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      102/10/14
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      決標公告日期
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      102/10/18
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      是否刊登公報
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      底價金額是否公開
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      總決標金額是否公開
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <!-- 最低標標案才顯示是否依採購法第58條規定採次低標或次次低標決標 -->
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      契約是否訂有依物價指數調整價金規定
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      否
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      未列物價調整規定說明
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      財物案
#     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      履約執行機關
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
#      機關代碼：3.7.74.37
#      <br>
#       機關名稱：臺灣菸酒股份有限公司隆田酒廠
#      </br>
# </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">
#      附加說明
#     </th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <!-- delimiter 決標資料 End -->
# <!-- delimiter 撤銷公告 Start -->
# <!-- delimiter 撤銷公告 End -->
# </tbody>
# </table>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-172-5c0b1ef666ed> in <module>()
#       1 ele = get_response_element('51081295_102-0400-1-051.txt')
#       2 award_info_dic = get_award_info_dic(ele)
# ----> 3 tenderer_info_dic = get_tenderer_info_dic(ele)
#       4 tender_award_item_dic = get_tender_award_item_dic(ele)
#       5
#
# NameError: name 'get_tenderer_info_dic' is not defined

# %%
print ', '.join(award_info_dic.keys())
print len(award_info_dic)
print '? '.len(award_info_dic)

columns = ', '.join(award_info_dic.keys()) 
placeholders = ', '.join('?' * len(award_info_dic)) 
print columns
print placeholders

sql = 'INSERT INTO Tender_awards ({}) VALUES ({})'.format(columns, placeholders) 
#print sql
#cur.execute(sql, award_info_dic.values())
#db.commit()

print tenderer_info_dic
# Out:
# entity_code, procuring_entity
# 2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-166-082ebdd3937e> in <module>()
#       1 print ', '.join(award_info_dic.keys())
#       2 print len(award_info_dic)
# ----> 3 print '? '.len(award_info_dic)
#       4
#       5 columns = ', '.join(award_info_dic.keys())
#
# AttributeError: 'str' object has no attribute 'len'

# %%
tenderer_sql = 'INSERT INTO Tenderer (pkAtmMain, job_number, tenderer_code, tenderer_name, awarded, orgnization_type, tenderer_num) VALUES (?,?,?,?,?,?,?) '

filename = "51081295_102-0400-1-051.txt"
file_param = filename.split(".txt")[0].split("_") 
pkAtmMain = file_param[0] 
job_number = '_'.join(file_param[1:]) 

for ele in tenderer_info_dic : 
        cur.execute(tenderer_sql , (pkAtmMain, job_number,  
          tenderer_info_dic[ele]["tenderer_code"],   
          tenderer_info_dic[ele]["tenderer_name"], 
          tenderer_info_dic[ele]["awarded"], 
          tenderer_info_dic[ele]["orgnization_type"], ele))
#db.commit() 
#db.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-168-673774a931c2> in <module>()
#       6 job_number = '_'.join(file_param[1:])
#       7
# ----> 8 for ele in tenderer_info_dic :
#       9         cur.execute(tenderer_sql , (pkAtmMain, job_number,
#      10           tenderer_info_dic[ele]["tenderer_code"],
#
# NameError: name 'tenderer_info_dic' is not defined

# %%
import sqlite3 as lite

salary = (
    (1 ,          'Paul'  ,      32 ,         'California',  20000),
    (2 ,          'Allen' ,      25 ,         'Texas'     ,  15000),
    (3 ,          'Teddy' ,      23 ,         'Norway'    ,  20000),
    (4 ,          'Mark'  ,      25 ,         'Rich-Mond' ,  65000),
    (5 ,          'David' ,      27 ,         'Texas'     ,  85000),
    (6 ,          'Kim'   ,      22 ,         'South-Hall',  45000),
    (7 ,          'James' ,      24 ,         'Houston'   ,  10000)
)
department = (
(1,           'IT Billing'  ,1),
(2,           'Engineerin'  ,2),
(3,           'Finance'     ,7),
(4,           'Finance'     ,5),
(5,           'Finance'     ,6)

)

con = lite.connect('test.db')

with con:
    
    cur = con.cursor()    
    
    cur.execute("DROP TABLE IF EXISTS Salary")
    cur.execute("DROP TABLE IF EXISTS Department")
    
    cur.execute("CREATE TABLE Salary(ID INT, NAME TEXT, AGE INT, ADDRESS TEXT, SALARY INT, FOREIGN KEY(ID) REFERENCES QOO(EMP_ID))")
    cur.executemany("INSERT INTO Salary VALUES(?, ?, ?, ?, ?)", salary)
    
    
    cur.execute("CREATE TABLE Department(ID INT PRIMARY KEY, DEPT CHAR(50), EMP_ID INT)")
    cur.executemany("INSERT INTO Department VALUES(?, ?, ?)", department)
con.close()

# %%
import time
dbname = 'test.db'
con = lite.connect(dbname)

items = tuple(range(1,100000))
with con:
    
    cur = con.cursor()    
    
    cur.execute("DROP TABLE IF EXISTS ptest")
    cur.execute("CREATE TABLE ptest(ID INT)")
    start = time.time()
    for i in range(0,100000):
        cur.execute("INSERT INTO ptest VALUES(%s)"%(i))
    end = time.time()
    print end -start
    cur.execute("select count(1) from ptest")
    rows = cur.fetchone()
    print rows

con.close()
# Out:
# 1.1218419075
# (100000,)

# %%
dbname = 'test.db'
con = lite.connect(dbname)
with con:
    
    cur = con.cursor()    
    
    cur.execute("DROP TABLE IF EXISTS ptest")
    cur.execute("CREATE TABLE ptest(ID INT)")
    start = time.time()
    cur.executemany("INSERT INTO ptest VALUES(?)",((id_, ) for id_ in xrange(100000)))
    end = time.time()
    print end - start
    cur.execute("select count(1) from ptest")
    rows = cur.fetchone()
    print rows

con.close()
# Out:
# 0.26569890976
# (100000,)
