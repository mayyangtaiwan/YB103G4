# %%
import requests
from bs4 import BeautifulSoup
res = requests.get("http://www.wranb.gov.tw/lp.asp?CtNode=317&CtUnit=92&BaseDSD=7&mp=5&nowPage=1&pagesize=180")
soup = BeautifulSoup(res.text)
for item in soup.select(".headline table tr"):
    if len(item.select('td')) > 0:
        print item.select('td')[0].text, item.select('td')[1].text, item.select('td')[3].text
# Out:
# 2015-03-30 面對旱象，除了進行各項節水抗旱作業外，北水局更積極應變，化危機為轉機，擴大清淤、辦理水庫設施改善等作業，為水庫永續繼續努力 北水局
# 2015-03-27 經濟部水利署北區水資源局徵水利工程職系工程員1名 人事室
# 2015-03-20 石門水庫增設取水工工程，把握水位下降進場施工，完成後提供更質優量穩水源  --  (資料來源：水利署) 北水局
# 2015-03-20 67年來最少雨 桃園、板新、林口地區4月1日起供5停2--(資料來源：水利署) 經管課
# 2015-03-20 本局經管桃園市龍潭區佳安里佳安西路5號佳安市場（碧湖段718建號、基地座落：碧湖段891、897地號土地）國有房地公開標租案 資產課
# 2015-03-14 總統視察寶二水庫供水情勢及抗旱措施  --  (資料來源：水利署) 北水局
# 2015-03-13 公告本局104年約僱人員（保育課職務代理人）甄選結果。 人事室
# 2015-03-11 經濟部水利署北區水資源局徵約僱人員（職務代理） 人事室
# 2015-03-07 石門水庫水位低，馬總統籲請全民行動抗旱  --  (資料來源：水利署) 北水局
# 2015-03-05 毛院長視察石門水庫水情及清淤辦理情形  --  (資料來源：水利署) 北水局
# 2015-03-02 北水局廉政電子報104年3月號  政風室
# 2015-02-26 公告本局104年約僱人員(主計室職務代理人)甄選錄取人員名單 人事室
# 2015-02-23 抗旱不休假，楊次長率水利署走訪北中南水庫，指示待命施作人工增雨--(資料來源：水利署) 經管課
# 2015-02-23 本波鋒面人工增雨南部效果較佳--(資料來源：水利署) 經管課
# 2015-02-11 新北（林口、板新）、桃竹苗、臺中、北彰化、臺南及高雄地區2月26日起二階限水--(資料來源：水利署) 經管課
# 2015-02-04 北水局廉政電子報104年2月號  政風室
# 2015-02-03 經濟部水利署北區水資源局徵約僱人員（職務代理） 人事室
# 2015-02-02 經濟部水利署北區水資源局徵約僱人員（職務代理） 人事室
# 2015-01-31 水情持續不佳，石門大圳延後一周供灌，請民眾加強節水共度枯水期 經管課
# ...

# %%
# -*- coding: utf-8 -*- 
from bs4 import BeautifulSoup 
f = open('51081295_102-0400-1-051.txt', 'r') 
response_text = f.read() 
soup = BeautifulSoup(''.join(response_text)) 

tr = soup.findAll('tr') 
#for row in tr: 
#    print row.find('th')

f.close()
# Out:
# <div class="main" id="printArea">
#  ﻿﻿﻿﻿﻿
#  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
#
# <head>
# <link href="/tps/styles/text.css" rel="stylesheet" type="text/css"/>
# <link href="/tps/styles/css.css" rel="stylesheet" type="text/css"/>
# <link href="/tps/styles/chtd_tab.css" rel="stylesheet" type="text/css"/>
# <link href="/tps/styles/chtd.css" rel="stylesheet" type="text/css"/>
# <style>
#    td {align: left;}
#   </style>
# </head>
# <script>
#   $jq(document).ready(function(){
# 	popWatermark();
# });
#
# function openEditScreen(editUrl){
#     window.open(encodeURI(editUrl));
#     unblock();
# }
#
# function popWatermark(){
# 	        var msgTop = 50;
# 	        var msgLeft = 500;
#
# 	        try{
# 	        	msgTop = $jq("#printArea").position().top+50;
# 	        	msgLeft = $jq("#printArea").position().left +$jq("#printArea").width()/2 +50;
# 			}catch(e) {}
#
# 			$jq("#hidden_message_id")
# 	        .css({
# ...
